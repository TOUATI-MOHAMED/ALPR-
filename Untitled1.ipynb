# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

#path=r"‪C:/avenguard/callable_plates/"
path=''
img1 = cv2.imread(r"SP 1281361.jpg",0)       # queryImage
img2 = cv2.imread(r'SP 281361.jpg',0) # trainImage
print (len(img1))
# Initiate SIFT detector
orb = cv2.ORB_create()

# find the keypoints and descriptors with SIFT
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)
#cv2.imshow('img2',img2)
#cv2.imshow('img1',img1)
#cv2.waitKey(0)
# Out:
# 273

# %%
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# Match descriptors.
try:
    5
    matches = bf.match(des1,des2)
except:
    matches = bf.match(des2,des1)

# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)

# Draw first 10 matches.
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],None, flags=2)

plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1351431bf60>, None)

# %%
# Initiate SIFT detector
sift = cv2.xfeatures2d.SIFT_create()

# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

# BFMatcher with default params
bf = cv2.BFMatcher()
try:
    matches = bf.knnMatch(des1,des2, k=2)
except:
    matches = bf.knnMatch(des1,des2, k=2) 

print(len(matches))
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
# cv2.drawMatchesKnn expects list of lists as matches.
print(len(good))
img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=2)

plt.imshow(img3),plt.show()
# Out:
# 1230
# 212
# (<matplotlib.image.AxesImage at 0x135144ff198>, None)

# %%
# Initiate SIFT detector
sift = cv2.xfeatures2d.SIFT_create()

# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

# FLANN parameters
FLANN_INDEX_KDTREE = 0
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks=50)   # or pass empty dictionary

flann = cv2.FlannBasedMatcher(index_params,search_params)

matches = flann.knnMatch(des1,des2,k=2)
print(len(matches))
# Need to draw only good matches, so create a mask
matchesMask = [[0,0] for i in range (len(matches))]
gd=0
# ratio test as per Lowe's paper
for i,(m,n) in enumerate(matches):
    if m.distance < 0.7*n.distance:
        matchesMask[i]=[1,0]
        gd=gd+1
print(gd)
draw_params = dict(matchColor = (255,0,0),
                   singlePointColor = (0,0,255),
                   matchesMask = matchesMask,
                   flags = 0)

#img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2,matches,None,flags=2)
img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2,matches,None,**draw_params)
plt.imshow(img3,),plt.show()
# Out:
# 1230
# 184
# (<matplotlib.image.AxesImage at 0x1351b4c43c8>, None)

# %%
import os
os.path.isfile('‪‪org.png')
# Out:
# False

# %%
path=os.path.abspath("../")
path=path+'\\ALPR'
print (path)
file=path+'\\org.png'
print (file)
# Out:
# C:\Users\avens\Documents\Avenguard\ALPR
# C:\Users\avens\Documents\Avenguard\ALPR\org.png

# %%
os.path.isfile(file)
# Out:
# True

# %%
path=os.path.abspath("../../../../..")
path=path+"\\avenguard\\callable_plates"
file=path+"\\0I093.jpg"
file
# Out:
# 'C:\\\\avenguard\\callable_plates\\0I093.jpg'

# %%
os.path.isfile(file)
# Out:
# True

# %%
import cv2
img1 = cv2.imread(r"SP 1281361.jpg",0)       # queryImage
img2 = cv2.imread(r'SP 281361.jpg',0) # trainImage
def compare_plates(img1,img2):
    # Initiate SIFT detector
    sift = cv2.xfeatures2d.SIFT_create()

    # find the keypoints and descriptors with SIFT
    kp1, des1 = sift.detectAndCompute(img1,None)
    kp2, des2 = sift.detectAndCompute(img2,None)

    # BFMatcher with default params
    bf = cv2.BFMatcher()
    try:
        matches = bf.knnMatch(des1,des2, k=2)
    except:
        matches = bf.knnMatch(des1,des2, k=2) 

    #print(len(matches))
    # Apply ratio test
    good = []
    for m,n in matches:
        if m.distance < 0.75*n.distance:
            good.append([m])

    return (len(good))>100
compare_plates(img1,img2)
# Out:
# True
